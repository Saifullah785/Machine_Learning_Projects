# %% [markdown]
# <a href="https://colab.research.google.com/github/Saifullah785/Machine_Learning_Projects/blob/main/Project_04_Isreal_and_Palestine_Fatalities_Analysis/Project_04_Isreal_and_Palestine_Fatalities_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import the pandas library for data manipulation
import pandas as pd

# %%
# Load the dataset from a CSV file into a pandas DataFrame

df = pd.read_csv("/content/fatalities.csv")

# %%
# Display the first few rows of the DataFrame to get an overview

df.head()
# Out:
#                                           name date_of_event   age  \
# 0  'Abd a-Rahman Suleiman Muhammad Abu Daghash    2023-09-24  32.0
# 1         Usayed Farhan Muhammad 'Ali Abu 'Ali    2023-09-24  21.0
# 2             'Abdallah 'Imad Sa'ed Abu Hassan    2023-09-22  16.0
# 3             Durgham Muhammad Yihya al-Akhras    2023-09-20  19.0
# 4                 Raafat 'Omar Ahmad Khamaisah    2023-09-19  15.0
#
#    citizenship     event_location event_location_district  \
# 0  Palestinian     Nur Shams R.C.                 Tulkarm
# 1  Palestinian     Nur Shams R.C.                 Tulkarm
# 2  Palestinian           Kfar Dan                   Jenin
# 3  Palestinian  'Aqbat Jaber R.C.                 Jericho
# 4  Palestinian         Jenin R.C.                   Jenin
#
#   event_location_region date_of_death gender took_part_in_the_hostilities  \
# 0             West Bank    2023-09-24      M                          NaN
# ...

# %% [markdown]
# #**2.Important Information**

# %%
# Calculate the counts of fatalities by citizenship

citizenship_counts = df['citizenship'].value_counts()

# Calculate the counts of fatalities by event location region

event_location_region = df['event_location_region'].value_counts()

# Calculate the counts of fatalities by citizenship for those who took part in hostilities
hostilities_counts = df[df['took_part_in_the_hostilities'] == 'Yes']['citizenship'].value_counts()

## Calculate the counts of fatalities by citizenship for those who did not take part in hostilities
no_hostilities_counts = df[df['took_part_in_the_hostilities'] == 'No']['citizenship'].value_counts()

# Number of events
num_events = len(df)

# Types of weapons used
weapons_used = df['ammunition'].value_counts()

# %% [markdown]
# # **Types of fires**

# %%
# Plot a bar chart of the value counts of 'type_of_injury'

df['type_of_injury'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='type_of_injury'>

# %% [markdown]
# # **Group data by 'gender' and visualize**

# %%
# Plot a bar chart of the value counts of 'gender'

df['gender'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='gender'>

# %% [markdown]
# # **Calculate Summary statistics for 'Age'**

# %%
# # **Calculate Summary statistics for 'Age'**
df.age.describe()
# Out:
# count    10995.000000
# mean        26.745703
# std         13.780548
# min          1.000000
# 25%         19.000000
# 50%         23.000000
# 75%         31.000000
# max        112.000000
# Name: age, dtype: float64

# %% [markdown]
# # **Group data by 'event_location_region' and count incidents**

# %%
# Plot a bar chart of the value counts of 'event_location_region

df['event_location_region'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='event_location_region'>

# %% [markdown]
# # **Count unique values of 'place_of_residence' within each region**

# %%
# Group by 'event_location_region' and count the number of unique 'place_of_residence' in each group, then plot a pie chart

df.groupby('event_location_region')['place_of_residence'].nunique().plot(kind='pie')
# Out:
# <Axes: ylabel='place_of_residence'>

# %% [markdown]
# # **Calculate average age by 'event_location_region'**

# %%
# Group by 'event_location_region' and calculate the mean age for each group
df.groupby('event_location_region')['age'].mean()
# Out:
# event_location_region
# Gaza Strip    26.020224
# Israel        36.286776
# West Bank     26.421746
# Name: age, dtype: float64

# %% [markdown]
# # **Visualize the types of injuries using matplotlib**

# %%
# Display the value counts of 'type_of_injury'

df['type_of_injury'].value_counts()
# Out:
# type_of_injury
# gunfire                         9849
# explosion                        555
# shelling                         311
# stabbing                          48
# house demolition                  25
# hit by a vehicle                  18
# beating                            9
# stones throwing                    6
# fire                               4
# being bludgeoned with an axe       4
# physically assaulted               2
# physical assault                   1
# Strangulation                      1
# Name: count, dtype: int64

# %% [markdown]
# # **Grouping by 'citizenship' to find out how many incidents involve each nationality**

# %%
# Group by 'citizenship', count the occurrences, and reset the index to create a DataFrame

df.groupby('citizenship').size().reset_index(name='incident_count')
# Out:
#    citizenship  incident_count
# 0     American               1
# 1      Israeli            1029
# 2    Jordanian               2
# 3  Palestinian           10092

# %%
# Define a function to group by 'citizenship' and count incidents

def nationality_incident(df):
  nationality_incident = df.groupby('citizenship').size().reset_index(name='incident_count')
  return nationality_incident

nationality_incident(df)
# Out:
#    citizenship  incident_count
# 0     American               1
# 1      Israeli            1029
# 2    Jordanian               2
# 3  Palestinian           10092

# %% [markdown]
# # **Data filtering example: Incidents in a specific region with specific characteristics**

# %%
# Filter the DataFrame to show incidents in 'West Bank' with 'gunfire' as the type of injury

df[(df['event_location_region']=='West Bank') & (df['type_of_injury']=='gunfire')]
# Out:
#                                               name date_of_event   age  \
# 0      'Abd a-Rahman Suleiman Muhammad Abu Daghash    2023-09-24  32.0
# 1             Usayed Farhan Muhammad 'Ali Abu 'Ali    2023-09-24  21.0
# 2                 'Abdallah 'Imad Sa'ed Abu Hassan    2023-09-22  16.0
# 3                 Durgham Muhammad Yihya al-Akhras    2023-09-20  19.0
# 4                     Raafat 'Omar Ahmad Khamaisah    2023-09-19  15.0
# ...                                            ...           ...   ...
# 11119                             Binyamin Herling    2000-10-19  64.0
# 11120                  Farid Musa 'Issa a-Nesasreh    2000-10-17  28.0
# 11121                             Hillel Lieberman    2000-10-07  36.0
# 11122                    Fahed Mustafa 'Odeh Baker    2000-10-07  21.0
# 11123                            Wichlav Zalsevsky    2000-10-02  24.0
#
#        citizenship     event_location event_location_district  \
# ...
